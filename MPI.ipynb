# %%
# %%writefile arquivo.c
# #include <stdio.h>
# #include <stdlib.h>
# #include <math.h>
# #include <mpi.h>
# #include <sys/time.h>
#
# //#define start 1
# //#define end 15000
#
# int gcd(int u, int v) {
# 	if (v == 0)
# 		return u;
# 	return gcd(v, u % v);
# }
#
# int main(int argc, char **argv) {
#
#   int rank, size;
#   long int n_elem_proc;
#   int i;
#   long int last;
#   long int *num,*den,*elem;
# 	struct timeval inic,fim;
#
#   MPI_Init(&argc,&argv);
#   MPI_Comm_size(MPI_COMM_WORLD,&size);
#   MPI_Comm_rank(MPI_COMM_WORLD,&rank);
#
#   int start, end;
#   start=atoi(argv[1]);
#   end=atoi(argv[2]);
#   if (start <= 0 || end <= start){
#     if(rank==0){
#       printf("Start deve ser maior que 0 e End deve ser maior que Start");
#     }
#     MPI_Finalize();
#     return 0;
#   }
#
#
#   gettimeofday(&inic,0);
#   if (rank == 0){ //mestre
# 		printf("Numeros de %d ate %d\n", start, end);
#
#     last = end - start + 1; // calcula o indice do ultimo elemento
#
#     num = (long int*) calloc(sizeof(long int), last);
#     den = (long int*) calloc(sizeof(long int), last);
#     elem = (long int*) calloc(sizeof(long int), last);
#
#     n_elem_proc = last/size; // numero de elementos por processo
#
#     for(int i=start,j=0; i <= end; i++,j++){
#         elem[j]= i; // adiciona o valor do elemento a ser calculado ao vetor de elementos
#     }
# 	}
#
#   MPI_Bcast(&n_elem_proc, 1, MPI_LONG, 0, MPI_COMM_WORLD); // transmite o n de elementos para os processos slaves
#   MPI_Bcast(&last, 1, MPI_LONG, 0, MPI_COMM_WORLD); // transmite o indice do ultimo elemento para os slaves
#
#   long int k, *recbuf, *t_num,*t_den;
#   int *sendcounts, *displs;
#
#   recbuf = (long int*) calloc(sizeof(long int), (n_elem_proc));
#   t_num = (long int*) malloc(sizeof(long int) * (n_elem_proc));
#   t_den = (long int*) malloc(sizeof(long int) * (n_elem_proc));
#   sendcounts = (int*) malloc(sizeof(int) * (size));
#   displs = (int*) malloc(sizeof(int) * (size));
#
#   k=0;
#   for (i=0; i<size; i++)
#     {
#       if (i<size-1) sendcounts[i] = n_elem_proc;
#       else sendcounts[i] = last-k;
#       displs[i] = k;
#       k = k+sendcounts[i];
#     }
#   if(rank==0){
#       printf("send count \n");
#       for (i=0; i<size; i++){
#           printf("%d\n", sendcounts[i]);
#       }
#       printf("displs  \n");
#       for (i=0; i<size; i++){
#           printf("%d\n", displs[i]);
#       }
#   }
#
#   //ScatterV para tratar quando o número de elementos não for divisível pelo número de processos
#   //Sendcounts é o número de elementos para cada processo, acessado por sendcounts[rank]
#   //Displs é a primeira posição do vetor que o processo receberá
#   MPI_Scatterv(elem, sendcounts, displs, MPI_LONG, recbuf, sendcounts[rank], MPI_LONG, 0, MPI_COMM_WORLD);
#
# 	long int factor;
# 	long int sum, done, n;
#
#   printf("send count %d no rank %d\n", sendcounts[rank], rank);
# 	for (i = 0; i < sendcounts[rank]; i++) {
# 		sum = 1 + recbuf[i]; // adiciona 1 e o proprio elemento a soma do numerador
# 		done = recbuf[i];
# 		factor = 2;
# 		while (factor < (done/2)+1) {  // faz a soma dos elementos divisiveis por i
# 			if ((recbuf[i] % factor) == 0) {
# 				sum += (factor);
# 			}
# 			factor++;
# 		}
# 		t_num[i] = sum; // recebe a soma do elemento
# 		t_den[i] = recbuf[i]; // proprio numero
# 		n = gcd(t_num[i], t_den[i]); // mdc
# 		t_num[i] /= n; // simplifica a fraçao
# 		t_den[i] /= n; // simplifica a fraçao
# 	}
#
#   MPI_Gatherv(t_num, sendcounts[rank], MPI_LONG, num, sendcounts, displs, MPI_LONG, 0, MPI_COMM_WORLD); // Envia de volta os calculos de numerador para o rank root
#   MPI_Gatherv(t_den, sendcounts[rank], MPI_LONG, den, sendcounts, displs, MPI_LONG, 0, MPI_COMM_WORLD); // Envia de volta os calculos de denominador para o rank root
#
#   int count = 0;
#   if(rank == 0) {
#     for (i = 0; i < last; i++) {
#       for (int j = i + 1; j < last; j++) {
#         if ((num[i] == num[j]) && (den[i] == den[j])){
#             count+=1;
#             printf("%ld e %ld sao amigaveis\n", elem[i], elem[j]); // printa numeros mutuamente amigaveis
#         }
#       }
# 	  }
# 	}
#   printf("%d",count);
#   gettimeofday(&fim,0);
#   if(rank==0){
#     printf("\nElapsed time:%f sec\n", (fim.tv_sec+fim.tv_usec/1000000.) - (inic.tv_sec+inic.tv_usec/1000000.));
#
#     free(num);
#     free(den);
#     free(elem);
#   }
#   MPI_Finalize();
#
#   free(recbuf);
#   free(t_num);
#   free(t_den);
#   free(sendcounts);
#   free(displs);
#
# 	return EXIT_SUCCESS;
# }
# Out:
# Overwriting arquivo.c

# %%
# !mpicc arquivo.c -o m1 && mpiexec --mca orte_base_help_aggregate 0 --allow-run-as-root -n 4 m1 1 15001
# Out:
# Numeros de 1 ate 15001
# send count
# 3750
# 3750
# 3750
# 3751
# displs
# 0
# 3750
# 7500
# 11250
# send count 3750 no rank 1
# send count 3750 no rank 2
# send count 3750 no rank 0
# send count 3751 no rank 3
# 1 e 6 sao amigaveis
# 1 e 28 sao amigaveis
# 1 e 496 sao amigaveis
# 1 e 8128 sao amigaveis
# 6 e 28 sao amigaveis
# 6 e 496 sao amigaveis
# 6 e 8128 sao amigaveis
# 12 e 234 sao amigaveis
# 28 e 496 sao amigaveis
# 28 e 8128 sao amigaveis
# 30 e 140 sao amigaveis
# 30 e 2480 sao amigaveis
# 30 e 6200 sao amigaveis
# 40 e 224 sao amigaveis
# 42 e 3472 sao amigaveis
# 56 e 3724 sao amigaveis
# 60 e 1170 sao amigaveis
# 66 e 308 sao amigaveis
# 66 e 5456 sao amigaveis
# 78 e 364 sao amigaveis
# 78 e 6448 sao amigaveis
# 80 e 200 sao amigaveis
# 84 e 270 sao amigaveis
# 84 e 1488 sao amigaveis
# 84 e 1638 sao amigaveis
# 102 e 476 sao amigaveis
# 102 e 8432 sao amigaveis
# 114 e 532 sao amigaveis
# 114 e 9424 sao amigaveis
# 120 e 672 sao amigaveis
# 132 e 2574 sao amigaveis
# 135 e 819 sao amigaveis
# 138 e 644 sao amigaveis
# 138 e 11408 sao amigaveis
# 140 e 2480 sao amigaveis
# 140 e 6200 sao amigaveis
# 150 e 700 sao amigaveis
# 150 e 12400 sao amigaveis
# 168 e 11172 sao amigaveis
# 174 e 812 sao amigaveis
# 174 e 14384 sao amigaveis
# 186 e 868 sao amigaveis
# 204 e 3978 sao amigaveis
# 222 e 1036 sao amigaveis
# 228 e 4446 sao amigaveis
# 240 e 600 sao amigaveis
# 246 e 1148 sao amigaveis
# 252 e 4464 sao amigaveis
# 258 e 1204 sao amigaveis
# 270 e 1488 sao amigaveis
# 270 e 1638 sao amigaveis
# 276 e 5382 sao amigaveis
# 282 e 1316 sao amigaveis
# 300 e 5850 sao amigaveis
# 308 e 5456 sao amigaveis
# 318 e 1484 sao amigaveis
# 330 e 1540 sao amigaveis
# 348 e 6786 sao amigaveis
# 354 e 1652 sao amigaveis
# 360 e 2016 sao amigaveis
# 364 e 6448 sao amigaveis
# 366 e 1708 sao amigaveis
# 372 e 7254 sao amigaveis
# 390 e 1820 sao amigaveis
# 402 e 1876 sao amigaveis
# 420 e 7440 sao amigaveis
# 420 e 8190 sao amigaveis
# 426 e 1988 sao amigaveis
# 438 e 2044 sao amigaveis
# 440 e 2464 sao amigaveis
# 444 e 8658 sao amigaveis
# 474 e 2212 sao amigaveis
# 476 e 8432 sao amigaveis
# 492 e 9594 sao amigaveis
# 496 e 8128 sao amigaveis
# 498 e 2324 sao amigaveis
# 510 e 2380 sao amigaveis
# 516 e 10062 sao amigaveis
# 520 e 2912 sao amigaveis
# 532 e 9424 sao amigaveis
# 534 e 2492 sao amigaveis
# 540 e 3276 sao amigaveis
# 560 e 1400 sao amigaveis
# 564 e 10998 sao amigaveis
# 570 e 2660 sao amigaveis
# 582 e 2716 sao amigaveis
# 588 e 11466 sao amigaveis
# 606 e 2828 sao amigaveis
# 618 e 2884 sao amigaveis
# 636 e 12402 sao amigaveis
# 642 e 2996 sao amigaveis
# 644 e 11408 sao amigaveis
# 654 e 3052 sao amigaveis
# 660 e 12870 sao amigaveis
# 678 e 3164 sao amigaveis
# 680 e 3808 sao amigaveis
# 690 e 3220 sao amigaveis
# 700 e 12400 sao amigaveis
# 708 e 13806 sao amigaveis
# 720 e 1800 sao amigaveis
# 726 e 3388 sao amigaveis
# 732 e 14274 sao amigaveis
# 750 e 3500 sao amigaveis
# 756 e 13392 sao amigaveis
# 760 e 4256 sao amigaveis
# 762 e 3556 sao amigaveis
# 786 e 3668 sao amigaveis
# 812 e 14384 sao amigaveis
# 822 e 3836 sao amigaveis
# 834 e 3892 sao amigaveis
# 858 e 4004 sao amigaveis
# 864 e 936 sao amigaveis
# 870 e 4060 sao amigaveis
# 880 e 2200 sao amigaveis
# 894 e 4172 sao amigaveis
# 906 e 4228 sao amigaveis
# 920 e 5152 sao amigaveis
# 924 e 2970 sao amigaveis
# 930 e 4340 sao amigaveis
# 942 e 4396 sao amigaveis
# 978 e 4564 sao amigaveis
# 1002 e 4676 sao amigaveis
# 1014 e 4732 sao amigaveis
# 1038 e 4844 sao amigaveis
# 1040 e 2600 sao amigaveis
# 1074 e 5012 sao amigaveis
# 1080 e 6048 sao amigaveis
# 1080 e 6552 sao amigaveis
# 1086 e 5068 sao amigaveis
# 1092 e 3510 sao amigaveis
# 1110 e 5180 sao amigaveis
# 1122 e 5236 sao amigaveis
# 1146 e 5348 sao amigaveis
# 1158 e 5404 sao amigaveis
# 1160 e 6496 sao amigaveis
# 1182 e 5516 sao amigaveis
# 1194 e 5572 sao amigaveis
# 1230 e 5740 sao amigaveis
# 1240 e 6944 sao amigaveis
# 1254 e 5852 sao amigaveis
# 1266 e 5908 sao amigaveis
# 1290 e 6020 sao amigaveis
# 1320 e 7392 sao amigaveis
# 1326 e 6188 sao amigaveis
# 1338 e 6244 sao amigaveis
# 1360 e 3400 sao amigaveis
# 1362 e 6356 sao amigaveis
# 1374 e 6412 sao amigaveis
# 1398 e 6524 sao amigaveis
# 1410 e 6580 sao amigaveis
# 1428 e 4590 sao amigaveis
# 1434 e 6692 sao amigaveis
# 1446 e 6748 sao amigaveis
# 1480 e 8288 sao amigaveis
# 1482 e 6916 sao amigaveis
# 1485 e 9009 sao amigaveis
# 1488 e 1638 sao amigaveis
# 1506 e 7028 sao amigaveis
# 1518 e 7084 sao amigaveis
# 1520 e 3800 sao amigaveis
# 1542 e 7196 sao amigaveis
# 1560 e 8736 sao amigaveis
# 1578 e 7364 sao amigaveis
# 1590 e 7420 sao amigaveis
# 1596 e 5130 sao amigaveis
# 1614 e 7532 sao amigaveis
# 1626 e 7588 sao amigaveis
# 1640 e 9184 sao amigaveis
# 1650 e 7700 sao amigaveis
# 1662 e 7756 sao amigaveis
# 1680 e 4200 sao amigaveis
# 1686 e 7868 sao amigaveis
# 1698 e 7924 sao amigaveis
# 1720 e 9632 sao amigaveis
# 1734 e 8092 sao amigaveis
# 1758 e 8204 sao amigaveis
# 1770 e 8260 sao amigaveis
# 1794 e 8372 sao amigaveis
# 1830 e 8540 sao amigaveis
# 1840 e 4600 sao amigaveis
# 1842 e 8596 sao amigaveis
# 1866 e 8708 sao amigaveis
# 1878 e 8764 sao amigaveis
# 1880 e 10528 sao amigaveis
# 1890 e 10416 sao amigaveis
# 1902 e 8876 sao amigaveis
# 1914 e 8932 sao amigaveis
# 1932 e 6210 sao amigaveis
# 1938 e 9044 sao amigaveis
# 1950 e 9100 sao amigaveis
# 1986 e 9268 sao amigaveis
# 2010 e 9380 sao amigaveis
# 2022 e 9436 sao amigaveis
# 2040 e 11424 sao amigaveis
# 2046 e 9548 sao amigaveis
# 2082 e 9716 sao amigaveis
# 2094 e 9772 sao amigaveis
# 2118 e 9884 sao amigaveis
# 2120 e 11872 sao amigaveis
# 2130 e 9940 sao amigaveis
# 2154 e 10052 sao amigaveis
# 2160 e 5400 sao amigaveis
# 2160 e 13104 sao amigaveis
# 2166 e 10108 sao amigaveis
# 2190 e 10220 sao amigaveis
# 2202 e 10276 sao amigaveis
# 2238 e 10444 sao amigaveis
# 2262 e 10556 sao amigaveis
# 2274 e 10612 sao amigaveis
# 2280 e 12768 sao amigaveis
# 2295 e 13923 sao amigaveis
# 2298 e 10724 sao amigaveis
# 2320 e 5800 sao amigaveis
# 2334 e 10892 sao amigaveis
# 2346 e 10948 sao amigaveis
# 2360 e 13216 sao amigaveis
# 2370 e 11060 sao amigaveis
# 2382 e 11116 sao amigaveis
# 2406 e 11228 sao amigaveis
# 2418 e 11284 sao amigaveis
# 2436 e 7830 sao amigaveis
# 2440 e 13664 sao amigaveis
# 2442 e 11396 sao amigaveis
# 2454 e 11452 sao amigaveis
# 2480 e 6200 sao amigaveis
# 2490 e 11620 sao amigaveis
# 2514 e 11732 sao amigaveis
# 2526 e 11788 sao amigaveis
# 2550 e 11900 sao amigaveis
# 2586 e 12068 sao amigaveis
# 2598 e 12124 sao amigaveis
# 2604 e 8370 sao amigaveis
# 2622 e 12236 sao amigaveis
# 2634 e 12292 sao amigaveis
# 2640 e 6600 sao amigaveis
# 2658 e 12404 sao amigaveis
# 2670 e 12460 sao amigaveis
# 2694 e 12572 sao amigaveis
# 2706 e 12628 sao amigaveis
# 2742 e 12796 sao amigaveis
# 2766 e 12908 sao amigaveis
# 2778 e 12964 sao amigaveis
# 2802 e 13076 sao amigaveis
# 2838 e 13244 sao amigaveis
# 2850 e 13300 sao amigaveis
# 2874 e 13412 sao amigaveis
# 2886 e 13468 sao amigaveis
# 2910 e 13580 sao amigaveis
# 2922 e 13636 sao amigaveis
# 2946 e 13748 sao amigaveis
# 2958 e 13804 sao amigaveis
# 2960 e 7400 sao amigaveis
# 2994 e 13972 sao amigaveis
# 3018 e 14084 sao amigaveis
# 3030 e 14140 sao amigaveis
# 3054 e 14252 sao amigaveis
# 3090 e 14420 sao amigaveis
# 3102 e 14476 sao amigaveis
# 3108 e 9990 sao amigaveis
# 3120 e 7800 sao amigaveis
# 3126 e 14588 sao amigaveis
# 3138 e 14644 sao amigaveis
# 3162 e 14756 sao amigaveis
# 3174 e 14812 sao amigaveis
# 3198 e 14924 sao amigaveis
# 3210 e 14980 sao amigaveis
# 3280 e 8200 sao amigaveis
# 3375 e 6975 sao amigaveis
# 3440 e 8600 sao amigaveis
# 3444 e 11070 sao amigaveis
# 3612 e 11610 sao amigaveis
# 3760 e 9400 sao amigaveis
# 3920 e 9800 sao amigaveis
# 3948 e 12690 sao amigaveis
# 4080 e 10200 sao amigaveis
# 4240 e 10600 sao amigaveis
# 4320 e 4680 sao amigaveis
# 4452 e 14310 sao amigaveis
# 4560 e 11400 sao amigaveis
# 4720 e 11800 sao amigaveis
# 4880 e 12200 sao amigaveis
# 5040 e 12600 sao amigaveis
# 5360 e 13400 sao amigaveis
# 5400 e 13104 sao amigaveis
# 5520 e 13800 sao amigaveis
# 5586 e 6860 sao amigaveis
# 5680 e 14200 sao amigaveis
# 5840 e 14600 sao amigaveis
# 6048 e 6552 sao amigaveis
# 6750 e 13950 sao amigaveis
# 7440 e 8190 sao amigaveis
# 7448 e 10976 sao amigaveis
# 9504 e 10296 sao amigaveis
# 293
# Elapsed time:0.928880 sec
# 000
